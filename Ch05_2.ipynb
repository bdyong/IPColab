# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as pit
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/gsy.png')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pit.imshow (gimg1, cmap= 'gray')
cv2_imshow(gimg1)
# Out:
# (489, 658, 3)
# <PIL.Image.Image image mode=L size=658x489>

# %% [markdown]
# 5,5 blur 처리

# %%
outimg = cv2.blur(gimg1, (5,5))
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=658x489>

# %% [markdown]
# gaussian blur 처리

# %%
outimg = cv2.GaussianBlur(gimg1, (7,7), 5)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=658x489>

# %%
medianBlur 처리

# %%
outimg = cv2.medianBlur(gimg1, 7)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=658x489>

# %%
outimage = gimg1.copy()
blurImage = cv2.GaussianBlur(outimage, (7,7), 5)

x = 290
y = 220
size = 20

for h in range(y, y+size):
  for w in range(x, x+size):
    outimage[h][w] = 255

cv2_imshow(outimage)
# Out:
# <PIL.Image.Image image mode=L size=658x489>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pit.imshow (gimg1, cmap= 'gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg = cv2.GaussianBlur(gimg1, (7,7), 1)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# gimg1, 가중치, outimg, 가중치

# %%
edgeImage = cv2.addWeighted(gimg1, 1, outimg, -1, 0)
cv2_imshow(edgeImage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
unsharpImage = cv2.addWeighted(gimg1, 1, edgeImage, -1, 0)
cv2_imshow(unsharpImage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# ★ 언샤프 필터링

# %%
kernel3 = np.ones((3,3), np.float32) / 9.0
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 17/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(gimg1, -1, kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 주파수를 걸러낸다
# 높은 주파수를 걸러내며 낮은 주파수 통과 -> 블러링
